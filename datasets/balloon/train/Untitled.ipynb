# %%
import pandas as pd

# %%
pd.read_json('via_region_data.json').transpose()['regions'][0]
# Out:
# {'0': {'region_attributes': {},
#   'shape_attributes': {'all_points_x': [1757,
#     1772,
#     1787,
#     1780,
#     1764,
#     1739,
#     1708,
#     1655,
#     1615,
#     1556,
#     1506,
#     1437,
#     1381,
#     1327,
#     1293,
#     1252,
#     1220,
#     1217,
#     1202,
#     1207,
#     1217,
#     1217,
#     1227,
#     1217,
#     1221,
#     1222,
#     1207,
#     1197,
#     1177,
#     1172,
#     1172,
#     1179,
#     1179,
#     1175,
#     1171,
#     1172,
#     1174,
#     1174,
#     1185,
#     1181,
#     1174,
#     1172,
#     1172,
#     1175,
#     1152,
#     1125,
#     1082,
#     1035,
#     1006,
#     983,
#     968,
#     964,
#     971,
#     991,
#     1022,
#     1072,
#     1118,
#     1192,
#     1232,
#     1270,
#     1333,
#     1392,
#     1453,
#     1511,
#     1554,
#     1622,
#     1664,
#     1694,
#     1719,
#     1741,
#     1757],
#    'all_points_y': [867,
#     913,
#     986,
#     1104,
#     1170,
# ...
